# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('sample_multifeature_data.csv')
df
# Out:
#           Age        Income  Experience  Education        Target
# 0   54.967142  12923.146290   26.788937   0.585502  25957.993835
# 1   48.617357  17896.773386   27.803923   0.719909  35895.298757
# 2   56.476885  18286.427417   30.415256   1.373647  36703.583278
# 3   65.230299  15988.613654   30.269010   1.305185  32134.510420
# 4   47.658466  19193.571442   18.111653   0.989549  38503.397894
# ..        ...           ...         ...        ...           ...
# 95  35.364851  21926.586899   21.535452   0.765412  43936.181332
# 96  52.961203  15580.712819   29.497999   0.143433  31266.406949
# 97  52.610553  20768.625530   26.536498   1.676936  41661.759265
# 98  50.051135  20291.043592   29.064311   0.942730  40684.601590
# 99  47.654129  14285.148511   28.148144   1.618908  28665.303735
#
# [100 rows x 5 columns]

# %%
#split df into feature/independant and target/dependant
x = df.iloc[:,:-1].values
x[0:5]
# Out:
# array([[5.49671415e+01, 1.29231463e+04, 2.67889368e+01, 5.85502495e-01],
#        [4.86173570e+01, 1.78967734e+04, 2.78039226e+01, 7.19909480e-01],
#        [5.64768854e+01, 1.82864274e+04, 3.04152562e+01, 1.37364680e+00],
#        [6.52302986e+01, 1.59886137e+04, 3.02690103e+01, 1.30518513e+00],
#        [4.76584663e+01, 1.91935714e+04, 1.81116532e+01, 9.89549203e-01]])

# %%
y = df.iloc[:,1].values
y[0:5]
# Out:
# array([12923.14628975, 17896.77338617, 18286.42741737, 15988.61365389,
#        19193.57144167])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
error = y_pred - y_test
error
# Out:
# array([-7.27595761e-12, -3.63797881e-12, -7.27595761e-12, -7.27595761e-12,
#         0.00000000e+00, -9.09494702e-12, -3.63797881e-12, -3.63797881e-12,
#        -3.63797881e-12, -3.63797881e-12, -3.63797881e-12, -3.63797881e-12,
#        -3.63797881e-12,  7.27595761e-12, -3.63797881e-12, -9.09494702e-12,
#         3.63797881e-12,  0.00000000e+00, -3.63797881e-12, -3.63797881e-12])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 1.0

# %%
class CustomLinearRegression:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.w = None
        self.b = None

    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        
        # Check for NaN or Inf values
        if np.isnan(X).any() or np.isnan(y).any():
            raise ValueError("Input contains NaN values.")
        if np.isinf(X).any() or np.isinf(y).any():
            raise ValueError("Input contains infinity values.")
        
        # Add intercept column (ones) for the bias term
        X = np.c_[np.ones(X.shape[0]), X]  # Adding a column of ones for the bias term
        
        # Closed-form solution: w = (X^T * X)^-1 * X^T * y
        self.w = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
        self.b = self.w[0]
        self.w = self.w[1:]

    def predict(self, X):
        # Convert X to a NumPy array
        X = np.array(X)

        # Check for invalid inputs
        if np.isnan(X).any():
            raise ValueError("Input contains NaN values. Please clean your data.")
        if np.isinf(X).any():
            raise ValueError("Input contains infinity values. Please clean your data.")

        # Prediction
        return np.dot(X, self.w) + self.b  # Linear prediction for multiple features

# %%
custom_model = CustomLinearRegression(learning_rate=0.01, epochs=1000)
custom_model.fit(x_train, y_train)

# %%
custom_y_pred = custom_model.predict(x_test)

# %%
custom_error = custom_y_pred - y_test
custom_error
# Out:
# array([8.91304808e-11, 3.63797881e-11, 5.09317033e-11, 1.81898940e-11,
#        2.54658516e-11, 8.73114914e-11, 8.00355338e-11, 2.91038305e-11,
#        2.18278728e-11, 6.91215973e-11, 3.63797881e-11, 4.00177669e-11,
#        7.63975549e-11, 9.45874490e-11, 2.54658516e-11, 6.18456397e-11,
#        3.63797881e-11, 4.36557457e-11, 5.82076609e-11, 6.54836185e-11])

# %%
compare_error = error-custom_error
compare_error
# Out:
# array([-9.64064384e-11, -4.00177669e-11, -5.82076609e-11, -2.54658516e-11,
#        -2.54658516e-11, -9.64064384e-11, -8.36735126e-11, -3.27418093e-11,
#        -2.54658516e-11, -7.27595761e-11, -4.00177669e-11, -4.36557457e-11,
#        -8.00355338e-11, -8.73114914e-11, -2.91038305e-11, -7.09405867e-11,
#        -3.27418093e-11, -4.36557457e-11, -6.18456397e-11, -6.91215973e-11])

# %%
# Plot predicted vs actual (for test data)
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Ideal line
plt.xlabel('Actual Target')
plt.ylabel('Predicted Target')
plt.title('Predicted vs Actual (Test Data)')
plt.legend()
plt.show()

# %%
# Plot predicted vs actual (for test data)
plt.figure(figsize=(8, 6))
plt.scatter(y_test, custom_y_pred, color='blue', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Ideal line
plt.xlabel('Actual Target')
plt.ylabel('Predicted Target')
plt.title('Predicted vs Actual (Test Data)')
plt.legend()
plt.show()

# %%
# Create a plot to compare the predictions from both models
plt.figure(figsize=(8, 6))

# Scatter plot for scikit-learn predictions (circle markers)
plt.scatter(y_test, y_pred, color='blue', label='Scikit-Learn Predictions', marker='o', alpha=0.5)

# Scatter plot for custom model predictions (cross markers)
plt.scatter(y_test, custom_y_pred, color='red', label='Custom Model Predictions', marker='x', alpha=0.5)

# Ideal line (perfect predictions) for reference
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='green', linestyle='--', label='Ideal Prediction')

plt.xlabel('Actual Target')
plt.ylabel('Predicted Target')
plt.title('Comparison of Predictions: Scikit-Learn vs Custom Model')
plt.legend()
plt.show()
