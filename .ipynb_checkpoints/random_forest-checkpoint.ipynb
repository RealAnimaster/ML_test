# %%
#random forest
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("random_forest_data.csv")
df
# Out:
#      Feature_1  Feature_2  Feature_3  Feature_4  Target
# 0     0.185133   0.541901   0.872946   0.732225     2.0
# 1     0.806561   0.658783   0.692277   0.849196     2.0
# 2     0.249668   0.489425   0.221209   0.987668     1.0
# 3     0.944059   0.039427   0.705575   0.925248     2.0
# 4     0.180575   0.567945   0.915488   0.033946     2.0
# ..         ...        ...        ...        ...     ...
# 395   0.122921   0.888659   0.503084   0.449350     2.0
# 396   0.585865   0.624784   0.071776   0.682617     1.0
# 397   0.241932   0.713953   0.822535   0.803959     2.0
# 398   0.552501   0.520170   0.142876   0.775346     0.0
# 399   0.271409   0.496695   0.284274   0.133828     1.0
#
# [400 rows x 5 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(["Target"], axis = "columns"), df.Target, train_size = 0.8, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#note: default values of randomforestclassifier parameters
#n_estimators(int, number of parallel trees during each iter): default=100, min=2
#tree_method(str, to specify tree method): default = "auto", other values = "exact","approx","hist"
#min_child_weight(float, minimum sum of instance weight(hessian) needed in a child): default = 1
#colsample_bytree(float,subsample ratio of columns when constructing each tree): default = 1.0, ranges from 0 to 1.
#colsample_bylevel(float, subsample ratio of columns for each level): default = 1, ranges from 0 to 1.
#colsample_bynode(float, subsample ratio of columns for each split): default = 0.8, ranges from 0 to 1.
#gamma(float, minimum loss reduction required to make further partition on leaf node): default = 0.0.
#max_depth(int, maximum tree depth): default = 15, >0
#subsample(float, subsample ratio of training instance): default = 0.8, ranges from 0 to 1.
#reg_alpha(float, L1 regularization term on weights(xgb's alpha)): default = 0.0.
#reg_lambda(float, L2 regularization term on weights(xgb's lambda)): default = 1.0.
#tol(float, minimum relative loss improvement needed to continue training): default = 0.01.
#enable_global_explain(bool, compute global explanations using explainable AI to evaluate global feature importance to model): default = false.
#xgboost_version(str, specifies xgboost version for model training): default = "0.9", other = "1.1",...

#class sklearn.ensemble.RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None, monotonic_cst=None)

# %%
model.score(x_test, y_test)
# Out:
# 0.8125

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot = True)
plt.xlabel("Prediction")
plt.ylabel("Actual")
# Out:
# Text(95.72222222222221, 0.5, 'Actual')

# %%
#model tuning with only n_estimators
#n_model = RandomForestClassifier(n_estimators=45)
#n_model.fit(x_train, y_train)
#n_model.score(x_test, y_test)
# high_score = 0
# req_estimators = 2
# for i in range(2,4):
#     n_model = RandomForestClassifier(n_estimators=i)
#     n_model.fit(x_train, y_train)
#     temp_score = n_model.score(x_test, y_test)
#     if temp_score>high_score:
#         high_score = temp_score
#         req_estimators = i
# print(high_score)
# print(req_estimators)

from sklearn.model_selection import cross_val_score

for i in range(2, 400):
    n_model = RandomForestClassifier(n_estimators=i, random_state=42)
    scores = cross_val_score(n_model, x_train, y_train, cv=3)  # Use 3 splits
    temp_score = scores.mean()
    if temp_score > high_score:
        high_score = temp_score
        req_estimators = i

# %%
req_estimators
# Out:
# 198

# %%
high_score
# Out:
# 0.809469229412802

# %%
#major parameters usually tuned
#n_estimators, max-depth, min_samples_split, min_samples_leaf, max_features, bootstrap

# %%
#fine tuning major parameters with randomized search
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter grid
param_dist = {
    "n_estimators": range(10, 240, 10),          # Number of trees
    "max_depth": [None, 10, 20, 30, 40, 50],    # Tree depth
    "min_samples_split": [2, 5, 10],            # Minimum samples to split
    "min_samples_leaf": [1, 2, 4],              # Minimum samples in leaf
    "max_features": ["sqrt", "log2", None],     # Features considered at each split
    "bootstrap": [True, False]                  # Bootstrap sampling
}

# RandomizedSearchCV
rf = RandomForestClassifier(random_state=42)
random_search = RandomizedSearchCV(
    estimator=rf, 
    param_distributions=param_dist,
    n_iter=100,          # Number of random combinations to try
    cv=3,                # 3-fold cross-validation
    verbose=2,           # Print progress
    random_state=42,
    n_jobs=-1            # Parallelism
)

# Fit the model
random_search.fit(x_train, y_train)

# Best parameters and score
print("Best parameters:", random_search.best_params_)
print("Best score:", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best parameters: {'n_estimators': 140, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}
# Best score: 0.8313642508669842

# %%
#refining with grid search for precision
from sklearn.model_selection import GridSearchCV

# Define the refined parameter grid
param_grid = {
    "n_estimators": [120, 140, 160],       # Refined around the best n_estimators
    "max_depth": [15, 20, 25],            # Refined around the best max_depth
    "min_samples_split": [2],             # Keep as is (best value)
    "min_samples_leaf": [1, 2, 3],        # Test nearby values
    "max_features": ["sqrt", "log2"],     # Test nearby options
    "bootstrap": [False]                  # Keep as is (best value)
}

# Initialize the RandomForestClassifier
rf = RandomForestClassifier(random_state=42)

# GridSearchCV for fine-tuning
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=3,               # 3-fold cross-validation
    verbose=2,          # Print progress
    n_jobs=-1           # Use all available cores
)

# Fit the model with the refined grid
grid_search.fit(x_train, y_train)

# Output the best parameters and score
print("Best parameters from grid search:", grid_search.best_params_)
print("Best score from grid search:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# Best parameters from grid search: {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 140}
# Best score from grid search: 0.8313642508669842

# %%
#comparing both models
# Randomized search model
random_model = RandomForestClassifier(**random_search.best_params_, random_state=42)
random_model.fit(x_train, y_train)
random_score = random_model.score(x_test, y_test)

# Grid search model
grid_model = RandomForestClassifier(**grid_search.best_params_, random_state=42)
grid_model.fit(x_train, y_train)
grid_score = grid_model.score(x_test, y_test)

print(f"Randomized Search Test Score: {random_score:.2f}")
print(f"Grid Search Test Score: {grid_score:.2f}")
# Out:
# Randomized Search Test Score: 0.78
# Grid Search Test Score: 0.78

# %%
#insights
#outcome suggests model performs equally well with different configs, so it's relatively robust
#max_depth is reduced from 20 to 15 but the score remains same, maybe indicates model is not benefitting from deeper trees, potentially avoids over fitting
#smaller depth reduces model complexity
#computational cost is reduced while maintaining performance
#model is likely relying on ensemble power (multiple trees) than depth of individual trees

# %%
# Final model with grid search parameters
final_model = RandomForestClassifier(
    **grid_search.best_params_,
    random_state=42
)
final_model.fit(x_train, y_train)

# Test the final model
final_score = final_model.score(x_test, y_test)
print(f"Final Model Test Score: {final_score:.2f}")
# Out:
# Final Model Test Score: 0.78
