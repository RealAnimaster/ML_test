# %%
#decision tree
import numpy as np
import pandas as pd
from sklearn import tree

# %%
df = pd.read_csv("decision_tree_data.csv")
df.head()
# Out:
#    Feature_1  Feature_2  Target
# 0   0.374540   0.950714     1.0
# 1   0.731994   0.598658     1.0
# 2   0.156019   0.155995     0.0
# 3   0.058084   0.866176     0.0
# 4   0.601115   0.708073     1.0

# %%
inputs = df.drop("Target", axis = "columns")
target = df["Target"]

# %%
inputs
# Out:
#      Feature_1  Feature_2
# 0     0.374540   0.950714
# 1     0.731994   0.598658
# 2     0.156019   0.155995
# 3     0.058084   0.866176
# 4     0.601115   0.708073
# ..         ...        ...
# 195   0.990505   0.412618
# 196   0.372018   0.776413
# 197   0.340804   0.930757
# 198   0.858413   0.428994
# 199   0.750871   0.754543
#
# [200 rows x 2 columns]

# %%
target
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 195    1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Name: Target, Length: 200, dtype: float64

# %%
#if feature data is not numerical and is categorical, need to encode them into numerical data
#this is called preprocessing
#decision tree only accepts numerical data
#one-hot encoding and label encoding are normally used for encoding purposes

#use below if dataset needs encoding
#from sklearn.preporcessing import LabelEncoder
#le_column1 = LabelEncoder() #<--- repeat for other columns that require preprocessing
#inputs['column1_n'] = le_column1.fit_transform(inputs['column1']) #<--- repeat for other columns that require preprocessing
#inputs_n = inputs.drop(['column1'],axis='columns') #<--- dropping columns not preprocessed and saving new columns to new input df

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs, target) #<--- use inputs_n if using preprocessed df
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs, target)
# Out:
# 1.0
